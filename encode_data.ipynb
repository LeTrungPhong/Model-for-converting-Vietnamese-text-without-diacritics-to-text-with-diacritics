# %%
from utils import build_vocab

IN_FILE_PATH = "dataset/train/cau_khong_dau.txt"
OUT_FILE_PATH = "dataset/train/label.txt"

DIM_MODEL = 512
N_HEADS = 8
N_LAYERS = 4
D_FF = 512
DROPOUT = 0.1

in_vocab = build_vocab(IN_FILE_PATH, max_len=10000, vocab_path="vocab/in_vocab.pkl")
out_vocab = build_vocab(OUT_FILE_PATH, max_len=10000, vocab_path="vocab/out_vocab.pkl")
# Out:
# Vocab not found at vocab/in_vocab.pkl, building vocab from scratch.
# Processing dataset/train/cau_khong_dau.txt,      6 | 26520
# Processing dataset/train/cau_khong_dau.txt,  26520 | 26520
# Vocab not found at vocab/out_vocab.pkl, building vocab from scratch.
# Processing dataset/train/label.txt,  26520 | 26520

# %%
import string

def encode_sentence(sentence, vocab, max_len):
    sentence = sentence.strip().lower()
    sentence = sentence.translate(str.maketrans("", "", string.punctuation))
    tokens = sentence.split()
    token_ids = [vocab.get(token, vocab['<unk>']) for token in tokens]
    token_ids = token_ids[:max_len] + [vocab['<pad>']] * (max_len - len(token_ids))
    return token_ids

def encode_decoder_sentence(sentence, vocab, max_len):
    sentence = sentence.strip().lower()
    sentence = sentence.translate(str.maketrans("", "", string.punctuation))
    tokens = sentence.split()

    full_tokens = [vocab['<seqstart>']] + \
                  [vocab.get(token, vocab['<unk>']) for token in tokens] + \
                  [vocab['<seqend>']]

    if len(full_tokens) < max_len:
        full_tokens += [vocab['<pad>']] * (max_len - len(full_tokens))
    else:
        full_tokens = full_tokens[:max_len]

    return full_tokens

encoder_sentence = "toi dang hoc lap trinh tri tue nhan tao"
encoder_decoder_sentence = "tôi đang học lập trình trí tuệ nhân tạo"

encoder_ids = encode_sentence(encoder_sentence, in_vocab, max_len=20)
decoder_ids = encode_decoder_sentence(encoder_decoder_sentence, out_vocab, max_len=20)

print("Encoder input:", encoder_ids)
print("Decoder input:", decoder_ids)
# Out:
# Encoder input: [18, 67, 55, 270, 135, 92, 616, 27, 150, 863, 863, 863, 863, 863, 863, 863, 863, 863, 863, 863]
# Decoder input: [1846, 18, 97, 24, 298, 83, 262, 1099, 50, 108, 1847, 1845, 1845, 1845, 1845, 1845, 1845, 1845, 1845, 1845]
